# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
# **To-Do:**
#
# As an employee of College Board, I am in a team that analyzes that trends and insights from the data we gathered each year to provide to our executive board. Since this is year 2020, we would like to evaluate the past year data as a whole and see if there are any key insights we can use to improve our test. Specifically, I wanted to look at the data by each state and by intended college major to see if there is any correlation between them. For example, are there any correlation between states that have high SAT scores and certain intended college majors.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **To-Do:**
#
# As an employee of College Board, I am in a team that analyzes that trends and insights from the data we gathered each year to provide to our executive board. Since this is year 2020, we would like to evaluate the past year data as a whole and see if there are any key insights we can use to improve our test. Specifically, I wanted to look at the data by each state and by intended college major to see if there is any correlation between them. For example, are there any correlation between states that have high SAT scores and certain intended college majors.

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*
#
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`SAT_dataframe.csv`](./data/SAT_dataframe.csv): Merge File between 2019 SAT Scores by State and 2019 SAT Scores by Intended College Major

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:**
# https://mapchart.net/usa.html

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
my_list = [2,3,4,5,6]

def mean_value(x):
    return sum(x)/len(x)

mean_value(my_list)
# Out:
# 4.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def std_value(x):
    summation = 0
    for i in range(len(x)):
        summation += (x[i] - mean_value(x))**2
    return (summation/len(x))**0.5
        
std_value(my_list)
# Out:
# 1.4142135623730951

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
def percent_convert(x):
    return float(x.strip('%'))/100

percent_convert('95%')
# Out:
# 0.95

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

plt.style.use('fivethirtyeight')
# %matplotlib inline

# Increase default figure and font sizes for easier viewing.
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
#import data
sat= pd.read_csv('./data/sat_2019.csv')
satm = pd.read_csv('./data/sat_2019_by_intended_college_major.csv')

# %% [markdown]
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.

# %%
sat.head(5)
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
satm.head(5)
# Out:
#                                 IntendedCollegeMajor TestTakers Percent  \
# 0  Agriculture, AgricultureOperations, and Relate...     24,913      1%
# 1                  Architecture and Related Services     28,988      2%
# 2         Area, Ethnic, Cultural, and Gender Studies      2,629      0%
# 3                 Biological and Biomedical Sciences    155,834      8%
# 4  Business, Management, Marketing, and Related S...    221,523     12%
#
#    Total  ReadingWriting  Math
# 0    977             496   481
# 1   1047             520   527
# 2   1040             536   504
# 3   1139             572   566
# 4   1072             534   537

# %%
sat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               53 non-null     object
#  1   Participation Rate  53 non-null     object
#  2   EBRW                53 non-null     int64
#  3   Math                53 non-null     int64
#  4   Total               53 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.2+ KB

# %%
satm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   IntendedCollegeMajor  38 non-null     object
#  1   TestTakers            38 non-null     object
#  2   Percent               38 non-null     object
#  3   Total                 38 non-null     int64
#  4   ReadingWriting        38 non-null     int64
#  5   Math                  38 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 1.9+ KB

# %% [markdown]
# 2. Check for missing values.

# %%
sat.shape
# Out:
# (53, 5)

# %%
sat.isnull().sum()
# Out:
# State                 0
# Participation Rate    0
# EBRW                  0
# Math                  0
# Total                 0
# dtype: int64

# %%
satm.shape
# Out:
# (38, 6)

# %%
satm.isnull().sum()
# Out:
# IntendedCollegeMajor    0
# TestTakers              0
# Percent                 0
# Total                   0
# ReadingWriting          0
# Math                    0
# dtype: int64

# %% [markdown]
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).

# %%
print(len(sat))
#The rows contain 50 states in the US, plus Hawaii, Alaska, and Virgin island. The data seems correct.
# Out:
# 53

# %%
#the total SAT score must have the range of 400-1600. The data seems correct.
len(sat[(400 <= sat['Total']) & (sat['Total'] <= 1600)])
# Out:
# 53

# %%
#Each section of SAT must have the score range of 200-800. The data seems correct.
len(sat[(200 <= sat['EBRW']) &  (sat['EBRW'] <= 800)])
# Out:
# 53

# %%
#Each section of SAT must have the score range of 200-800. The data seems correct.
len(sat[(200 <= sat['Math']) &  (sat['Math'] <= 800)])
# Out:
# 53

# %%
#which state has the maximum average total score
sat[sat['Total']==sat['Total'].max()]
# Out:
#         State Participation Rate  EBRW  Math  Total
# 23  Minnesota                 4%   636   648   1284

# %%
#which state has the minimum average total score
sat[sat['Total']==sat['Total'].min()]
# Out:
#              State Participation Rate  EBRW  Math  Total
# 47  Virgin Islands                  —   490   445    935

# %%
#From the SAT data by college major, there are 38 college majors, including undecided
print(len(satm))
# Out:
# 38

# %%
#the total SAT score must have the range of 400-1600. The data seems correct.
len(satm[(400 <= satm['Total']) & (satm['Total'] <= 1600)])
# Out:
# 38

# %%
#Each section of SAT must have the score range of 200-800. The data seems correct.
len(satm[(200 <= satm['ReadingWriting']) &  (satm['ReadingWriting'] <= 800)])
# Out:
# 38

# %%
#Each section of SAT must have the score range of 200-800. The data seems correct.
len(satm[(200 <= satm['Math']) &  (satm['Math'] <= 800)])
# Out:
# 38

# %%
#Check whether "Percent" means percetange of test takers per college major
#For TestTakers column, remove , and change obj to interger first
satm['TestTakers'] = satm['TestTakers'].map(lambda testers: int(testers.replace(',','')))

# %%
satm.TestTakers
# Out:
# 0      24913
# 1      28988
# 2       2629
# 3     155834
# 4     221523
# 5      36332
# 6      79736
# 7       2500
# 8      71882
# 9     194127
# 10     33595
# 11     16233
# 12      6469
# 13      9936
# 14    331026
# 15     12611
# 16     35788
# 17      8611
# 18       283
# 19     16508
# 20      6592
# 21      7448
# 22      2979
# 23     10147
# 24     13039
# 25      6668
# 26      3381
# 27     26318
# 28       319
# 29     75626
# 30      7852
# 31     68177
# 32     33356
# 33      1991
# 34      1105
# 35    130642
# 36     26888
# 37    126939
# Name: TestTakers, dtype: int64

# %%
#Find total number of test takers
satm.TestTakers.sum()
# Out:
# 1838991

# %%
#Round up the numbers
ROUND = round((satm.TestTakers /  satm.TestTakers.sum())*100, 0)
ROUND
# Out:
# 0      1.0
# 1      2.0
# 2      0.0
# 3      8.0
# 4     12.0
# 5      2.0
# 6      4.0
# 7      0.0
# 8      4.0
# 9     11.0
# 10     2.0
# 11     1.0
# 12     0.0
# 13     1.0
# 14    18.0
# 15     1.0
# 16     2.0
# 17     0.0
# 18     0.0
# 19     1.0
# 20     0.0
# 21     0.0
# 22     0.0
# 23     1.0
# 24     1.0
# 25     0.0
# 26     0.0
# 27     1.0
# 28     0.0
# 29     4.0
# 30     0.0
# 31     4.0
# 32     2.0
# 33     0.0
# 34     0.0
# 35     7.0
# 36     1.0
# 37     7.0
# Name: TestTakers, dtype: float64

# %%
#Remove % and change to integer for column Percent
satm['Percent'] = satm['Percent'].map(lambda percent: int(percent.replace('%','')))

# %%
#"Percent" accurately represents percetange of test takers per college major
ROUND == satm.Percent
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# 26    True
# 27    True
# 28    True
# 29    True
# 30    True
# 31    True
# 32    True
# 33    True
# 34    True
# 35    True
# 36    True
# 37    True
# dtype: bool

# %% [markdown]
# 4. Fix any errors you identified in steps 2-3.
#
# Already fixed

# %% [markdown]
# 5. Display the data types of each feature.

# %%
sat.dtypes
# Out:
# State                 object
# Participation Rate    object
# EBRW                   int64
# Math                   int64
# Total                  int64
# dtype: object

# %%
satm.dtypes
# Out:
# IntendedCollegeMajor    object
# TestTakers               int64
# Percent                  int64
# Total                    int64
# ReadingWriting           int64
# Math                     int64
# dtype: object

# %% [markdown]
# 6. Fix any incorrect data types found in step 5.

# %%
#remove % and - from Participation Rate
sat['Participation Rate'] = sat['Participation Rate'].str.replace(r'%','').replace(r'—','0')
sat['Participation Rate']
# Out:
# 0       7
# 1      41
# 2      31
# 3       6
# 4      63
# 5     100
# 6     100
# 7     100
# 8      94
# 9     100
# 10     71
# 11     54
# 12    100
# 13    100
# 14     66
# 15      3
# 16      4
# 17      4
# 18      5
# 19     99
# 20     82
# 21     81
# 22    100
# 23      4
# 24      3
# 25      4
# 26      9
# 27      3
# 28     20
# 29     95
# 30     82
# 31     18
# 32     79
# 33     51
# 34      2
# 35     19
# 36     22
# 37     51
# 38     70
# 39      0
# 40    100
# 41     68
# 42      3
# 43      7
# 44     68
# 45      4
# 46     66
# 47      0
# 48     68
# 49     70
# 50     99
# 51      3
# 52      3
# Name: Participation Rate, dtype: object

# %%
#convert Participation Rate to float
sat['Participation Rate'] = sat['Participation Rate'].map(lambda parti: float(parti))

# %%
sat.dtypes
# Out:
# State                  object
# Participation Rate    float64
# EBRW                    int64
# Math                    int64
# Total                   int64
# dtype: object

# %%
#convert Percent from int to float
satm['Percent'] = satm['Percent'].map(lambda percent: float(percent))

# %%
satm.dtypes
# Out:
# IntendedCollegeMajor     object
# TestTakers                int64
# Percent                 float64
# Total                     int64
# ReadingWriting            int64
# Math                      int64
# dtype: object

# %% [markdown]
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will   suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.

# %%
sat.columns
# Out:
# Index(['State', 'Participation Rate', 'EBRW', 'Math', 'Total'], dtype='object')

# %%
sat.columns = ['state','participationrate_state','verbal_state','math_state','total_state']

# %%
sat.head(5)
# Out:
#         state  participationrate_state  verbal_state  math_state  total_state
# 0     Alabama                      7.0           583         560         1143
# 1      Alaska                     41.0           556         541         1097
# 2     Arizona                     31.0           569         565         1134
# 3    Arkansas                      6.0           582         559         1141
# 4  California                     63.0           534         531         1065

# %%
satm.columns
# Out:
# Index(['IntendedCollegeMajor', 'TestTakers', 'Percent', 'Total',
#        'ReadingWriting', 'Math'],
#       dtype='object')

# %%
satm.columns = ['intended_major', 'participationnumber_major', 'participationrate_major','total_major','verbal_major','math_major']

# %%
satm.head(5)
# Out:
#                                       intended_major  \
# 0  Agriculture, AgricultureOperations, and Relate...
# 1                  Architecture and Related Services
# 2         Area, Ethnic, Cultural, and Gender Studies
# 3                 Biological and Biomedical Sciences
# 4  Business, Management, Marketing, and Related S...
#
#    participationnumber_major  participationrate_major  total_major  \
# 0                      24913                      1.0          977
# 1                      28988                      2.0         1047
# 2                       2629                      0.0         1040
# 3                     155834                      8.0         1139
# 4                     221523                     12.0         1072
#
#    verbal_major  math_major
# 0           496         481
# 1           520         527
# 2           536         504
# 3           572         566
# 4           534         537

# %% [markdown]
# 8. Drop unnecessary rows (if needed).

# %%
#drop 'participationnumber_major' because we already have participation rate 
satm.pop('participationnumber_major')
# Out:
# 0      24913
# 1      28988
# 2       2629
# 3     155834
# 4     221523
# 5      36332
# 6      79736
# 7       2500
# 8      71882
# 9     194127
# 10     33595
# 11     16233
# 12      6469
# 13      9936
# 14    331026
# 15     12611
# 16     35788
# 17      8611
# 18       283
# 19     16508
# 20      6592
# 21      7448
# 22      2979
# 23     10147
# 24     13039
# 25      6668
# 26      3381
# 27     26318
# 28       319
# 29     75626
# 30      7852
# 31     68177
# 32     33356
# 33      1991
# 34      1105
# 35    130642
# 36     26888
# 37    126939
# Name: participationnumber_major, dtype: int64

# %%
satm.head(5)
# Out:
#                                       intended_major  participationrate_major  \
# 0  Agriculture, AgricultureOperations, and Relate...                      1.0
# 1                  Architecture and Related Services                      2.0
# 2         Area, Ethnic, Cultural, and Gender Studies                      0.0
# 3                 Biological and Biomedical Sciences                      8.0
# 4  Business, Management, Marketing, and Related S...                     12.0
#
#    total_major  verbal_major  math_major
# 0          977           496         481
# 1         1047           520         527
# 2         1040           536         504
# 3         1139           572         566
# 4         1072           534         537

# %% [markdown]
# 9. Merge dataframes that can be merged.

# %%
df = pd.concat([sat,satm], axis = 1)
df
# Out:
#                    state  participationrate_state  verbal_state  math_state  \
# 0                Alabama                      7.0           583         560
# 1                 Alaska                     41.0           556         541
# 2                Arizona                     31.0           569         565
# 3               Arkansas                      6.0           582         559
# 4             California                     63.0           534         531
# 5               Colorado                    100.0           518         506
# 6            Connecticut                    100.0           529         516
# 7               Delaware                    100.0           499         486
# 8   District of Columbia                     94.0           495         480
# 9                Florida                    100.0           516         483
# 10               Georgia                     71.0           538         519
# ...

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %%
df.dtypes
# Out:
# state                       object
# participationrate_state    float64
# verbal_state                 int64
# math_state                   int64
# total_state                  int64
# intended_major              object
# participationrate_major    float64
# total_major                float64
# verbal_major               float64
# math_major                 float64
# dtype: object

# %% [markdown]
# **To-Do:**
#
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|sat_2019|List of US states, including Hawaii, Alaska, and Virgin island|
# |participationrate_state|float|sat_2019|Percentage of students who took SAT test in 2019 (by state)|
# |total_state|int|sat_2019|Total SAT score, range between 400 and 1600 (by state)|
# |verbal_state|int|sat_2019|SAT verbal score, range between 200 and 800 (by state)|
# |math_state|int|sat_2019|SAT math score, range between 200 and 800 (by state)|
# |intended_major|object|sat_2019_by_intended_college_major|Intended college major of the students who took SAT test in 2019|
# |participationrate_major|float|sat_2019_by_intended_college_major|Percentage of students who took SAT test in 2019 (by major)|
# |total_major|float|sat_2019_by_intended_college_major|Total SAT score, range between 400 and 1600 (by major)|
# |verbal_major|float|sat_2019_by_intended_college_major|SAT verbal score, range between 200 and 800 (by major)|
# |math_major|float|sat_2019_by_intended_college_major|SAT math score, range between 200 and 800 (by major)|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# 1. Summary Statistics.

# %%
df.describe()
# Out:
#        participationrate_state  verbal_state  math_state  total_state  \
# count                53.000000     53.000000   53.000000    53.000000
# mean                 47.207547    558.000000  548.471698  1106.528302
# std                  39.149790     47.554422   53.785044   100.994784
# min                   0.000000    483.000000  445.000000   935.000000
# 25%                   4.000000    518.000000  506.000000  1024.000000
# 50%                  51.000000    550.000000  545.000000  1097.000000
# 75%                  82.000000    610.000000  596.000000  1200.000000
# max                 100.000000    636.000000  648.000000  1284.000000
#
#        participationrate_major  total_major  verbal_major  math_major
# count                38.000000    38.000000     38.000000   38.000000
# mean                  2.578947  1058.500000    535.500000  523.000000
# std                   3.997510    82.445969     41.362439   43.386385
# ...

# %% [markdown]
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
def std_value_dict(df,column):
    mean = df[column].mean()
    number = df[column].count()
    summation = 0
    for i in df[column]:
        summation += (i - mean)**2
    return (summation/number)**0.5
        
std_value_dict(df,'math_state')
# Out:
# 53.27522124781091

# %%
def std_dict(dataframe,key):
    try: 
        int(datframe[key][1])
        return True
    except:
        return False

# %%
sd = {key :std_value_dict(df,key) for key in df.columns if (std_value_dict(df,key) =='float64')}
#???
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1426         try:
# -> 1427             x = float(x)
#    1428         except ValueError:
#
# ValueError: could not convert string to float: 'AlabamaAlaskaArizonaArkansasCaliforniaColoradoConnecticutDelawareDistrict of ColumbiaFloridaGeorgiaHawaiiIdahoIllinoisIndianaIowaKansasKentuckyLouisianaMaineMarylandMassachusettsMichiganMinnesotaMississippiMissouriMontanaNebraskaNevadaNew HampshireNew JerseyNew MexicoNew YorkNorth CarolinaNorth DakotaOhioOklahomaOregonPennsylvaniaPuerto RicoRhode IslandSouth CarolinaSouth DakotaTennesseeTexasUtahVermontVirgin IslandsVirginiaWashingtonWest VirginiaWisconsinWyoming'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ...

# %% [markdown]
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?

# %%
#top 5 states with highest SAT score
highscore_state = df.sort_values(by='total_state',ascending=False).head(5)
highscore_state
# Out:
#            state  participationrate_state  verbal_state  math_state  \
# 23     Minnesota                      4.0           636         648
# 51     Wisconsin                      3.0           635         648
# 42  South Dakota                      3.0           633         635
# 34  North Dakota                      2.0           627         636
# 27      Nebraska                      3.0           628         631
#
#     total_state                       intended_major  participationrate_major  \
# 23         1284   Natural resources and Conservation                      1.0
# 51         1283                                  NaN                      NaN
# 42         1268                                  NaN                      NaN
# 34         1263  Transportation and Materials Moving                      0.0
# 27         1260                    Physical Sciences                      1.0
#
#     total_major  verbal_major  math_major
# 23       1104.0         562.0       543.0
# ...

# %%
#top 5 states with highest SAT score
plt.figure(figsize=(10,5))
plt.bar(highscore_state['state'],highscore_state['total_state'],width=0.5,color='green');
plt.xlabel('States')
plt.ylabel('Total SAT Scores');
plt.xticks(rotation = 0);
plt.title('Top 5 States with Highest SAT Score');

# %% [markdown]
# The top 5 states with highest SAT scores are Minnesota, Wisconsin, South Dakota, North Dakota, and Nebraska.

# %%
#top 5 intended college major with highest SAT score
highscore_major = df.sort_values(by='total_major',ascending=False).head(5)
highscore_major
# Out:
#           state  participationrate_state  verbal_state  math_state  \
# 19        Maine                     99.0           512         502
# 27     Nebraska                      3.0           628         631
# 32     New York                     79.0           531         533
# 6   Connecticut                    100.0           529         516
# 22     Michigan                    100.0           507         496
#
#     total_state                                     intended_major  \
# 19         1013                         Mathematics and Statistics
# 27         1260                                  Physical Sciences
# 32         1064                                    Social Sciences
# 6          1046  Computer and Information Sciences and Support ...
# 22         1003                    Multi/Interdisciplinary Studies
#
#     participationrate_major  total_major  verbal_major  math_major
# 19                      1.0       1242.0         597.0       646.0
# ...

# %%
#top 5 intended college major with highest SAT score
import textwrap
plt.figure(figsize=(10,5))
plt.bar(highscore_major['intended_major'],highscore_major['total_major'],width=0.5,color='limegreen');
plt.xlabel('Intended College Major')
plt.ylabel('Total SAT Scores');
plt.xticks(rotation = 50);
plt.title('Top 5 Intended College Major with Highest SAT Score');

# %% [markdown]
# The top 5 intended college majors with highest SAT scores are Mathematics and Statistics, Physical Science, Social Science, Computer and Information Sciences, Multi/Interdisciplinary Studies.

# %%
#top 5 states with lowest SAT score
lowscore_state = df.sort_values(by='total_state',ascending=False).tail(5)
lowscore_state
# Out:
#                    state  participationrate_state  verbal_state  math_state  \
# 8   District of Columbia                     94.0           495         480
# 36              Oklahoma                     22.0           490         472
# 39           Puerto Rico                      0.0           483         462
# 50         West Virginia                     99.0           483         460
# 47        Virgin Islands                      0.0           490         445
#
#     total_state intended_major  participationrate_major  total_major  \
# 8           975      Education                      4.0       1022.0
# 36          963          Other                      1.0        963.0
# 39          944            NaN                      NaN          NaN
# 50          943            NaN                      NaN          NaN
# 47          935            NaN                      NaN          NaN
#
#     verbal_major  math_major
# 8          519.0       503.0
# 36         488.0       476.0
# ...

# %%
#top 5 states with lowest SAT score
plt.figure(figsize=(10,5))
plt.bar(lowscore_state['state'],lowscore_state['total_state'],width=0.5,color='red');
plt.xlabel('States')
plt.ylabel('Total SAT Scores');
plt.xticks(rotation = 0);
plt.title('Top 5 States with Lowest SAT Score');

# %% [markdown]
# The top 5 states with lowest SAT scores are District of Columbia, Oklahoma, Puerto Rico, West Virginia, and Virgin Islands

# %%
#top 5 intended college major with lowest SAT score
lowscore_major = df.sort_values(by='total_major',ascending=True).head(5)
lowscore_major
# Out:
#        state  participationrate_state  verbal_state  math_state  total_state  \
# 20  Maryland                     82.0           535         523         1058
# 7   Delaware                    100.0           499         486          985
# 25  Missouri                      4.0           622         615         1236
# 28    Nevada                     20.0           580         576         1156
# 12     Idaho                    100.0           505         488          993
#
#                                   intended_major  participationrate_major  \
# 20  Mechanic and Repair Technologies/Technicians                      0.0
# 7                   Construction Trades, General                      0.0
# 25       Personal and Culinary Services, General                      0.0
# 28                          Precision Production                      0.0
# 12   Family and Consumer Sciences/Human Sciences                      0.0
#
#     total_major  verbal_major  math_major
# ...

# %%
#top 5 college majors with lowest SAT score
plt.figure(figsize=(10,5))
plt.bar(lowscore_major['intended_major'],lowscore_major['total_major'],width=0.5,color='crimson');
plt.xlabel('Intended College Major')
plt.ylabel('Total SAT Scores');
plt.xticks(rotation = 30);
plt.title('Top 5 College Majors with Lowest SAT Score');

# %% [markdown]
# The top 5 intended college majors with lowest SAT scores are Mechanic and repair technolgies, Consturction Trades, Personal and Culinary Services, Precision Production, and Family and Consumer Sciences.
#
# These majors might not use SAT scores as a college admission test or SAT might not be an important part of their college applications.

# %%
#top 5 intended college major with highest math scores
highmathscore_major = df.sort_values(by='math_major',ascending=False).head(5)
highmathscore_major
# Out:
#           state  participationrate_state  verbal_state  math_state  \
# 19        Maine                     99.0           512         502
# 27     Nebraska                      3.0           628         631
# 6   Connecticut                    100.0           529         516
# 9       Florida                    100.0           516         483
# 22     Michigan                    100.0           507         496
#
#     total_state                                     intended_major  \
# 19         1013                         Mathematics and Statistics
# 27         1260                                  Physical Sciences
# 6          1046  Computer and Information Sciences and Support ...
# 9           999                                        Engineering
# 22         1003                    Multi/Interdisciplinary Studies
#
#     participationrate_major  total_major  verbal_major  math_major
# 19                      1.0       1242.0         597.0       646.0
# ...

# %%
#top 5 intended college major with highest math scores
plt.figure(figsize=(10,8))
plt.bar(highmathscore_major['intended_major'],highmathscore_major['math_major'],width=0.5,color='navy');
plt.xlabel('Intended College Major')
plt.ylabel('Math Scores');
plt.xticks(rotation = 60);
plt.title('Top 5 College Majors with Highest Math Score');

# %% [markdown]
# The top 5 intended college majors with highest Math scores are Mathematics and Statistics, Physical Science, Computer and Information Sciences, Engineering, and Multi/Interdisciplinary Studies.
#
# These college majors are similar to those with high total SAT scores, minus Social Science. These college majors will use math as their main subjects, so the data we gathered make sense as there must be correlation between those who did well in math and their preferred major in college.

# %%
#top 5 intended college major with highest verbal scores
highverbalscore_major = df.sort_values(by='verbal_major',ascending=False).head(5)
highverbalscore_major

#surprisingly math people still did good in verbal
# Out:
#        state  participationrate_state  verbal_state  math_state  total_state  \
# 19     Maine                     99.0           512         502         1013
# 27  Nebraska                      3.0           628         631         1260
# 32  New York                     79.0           531         533         1064
# 11    Hawaii                     54.0           550         550         1100
# 17  Kentucky                      4.0           620         612         1232
#
#                                        intended_major  \
# 19                         Mathematics and Statistics
# 27                                  Physical Sciences
# 32                                    Social Sciences
# 11            English Language and Literature/Letters
# 17  Liberal Arts and Sciences, General Studies and...
#
#     participationrate_major  total_major  verbal_major  math_major
# 19                      1.0       1242.0         597.0       646.0
# ...

# %%
#top 5 intended college major with highest verbal scores
plt.figure(figsize=(10,5))
plt.bar(highverbalscore_major['intended_major'],highverbalscore_major['verbal_major'],width=0.5,color='orange');
plt.xlabel('Intended College Major')
plt.ylabel('Verbal Scores');
plt.xticks(rotation = 60);
plt.title('Top 5 College Majors with Highest Verbal Score');

# %% [markdown]
# Surprisingly, the top 5 intended college majors with highest verbal scores are Mathematics and Statistics, Physical Science, Social Science, English Language and Literature, and Liberal Arts and Sciences.
#
# So, students who intended to major in Mathematics and Statistics and Physical Science did well in both verbal and math sections. On the other hand, students who intended to major in Social Science must have scored verbal section higher than math section in order to get high overall scores.

# %%
#top 5 intended college major with lowest test takers
lowtesttakers_major = df.sort_values(by='participationrate_major',ascending=True).head(15)
lowtesttakers_major

#maybe those majors require other tests.So, there's no need to take the SAT.
# Out:
#              state  participationrate_state  verbal_state  math_state  \
# 18       Louisiana                      5.0           610         591
# 20        Maryland                     82.0           535         523
# 21   Massachusetts                     81.0           559         561
# 22        Michigan                    100.0           507         496
# 12           Idaho                    100.0           505         488
# 25        Missouri                      4.0           622         615
# 7         Delaware                    100.0           499         486
# 26         Montana                      9.0           603         596
# 28          Nevada                     20.0           580         576
# 30      New Jersey                     82.0           544         545
# 33  North Carolina                     51.0           554         546
# 2          Arizona                     31.0           569         565
# ...

# %% [markdown]
# There are 14 intended college majors that have zero participation rate, meaning these data we gathered from the intended college major aspect might not have much importance compared to those with higher participant rates.
# On the other hand, we can also look at it as very little people who intended to study in these fields might not need the SAT to get acccepted took the SAT. Further analysis will be needed to come up with conclusion.

# %%
#top 5 intended college major with highest test takers
highesttakers_major = df.sort_values(by='participationrate_major',ascending=False).head(5)
highesttakers_major
# Out:
#          state  participationrate_state  verbal_state  math_state  \
# 14     Indiana                     66.0           543         537
# 4   California                     63.0           534         531
# 9      Florida                    100.0           516         483
# 3     Arkansas                      6.0           582         559
# 35        Ohio                     19.0           550         548
#
#     total_state                                     intended_major  \
# 14         1080   Health Professions and related Clinical Sciences
# 4          1065  Business, Management, Marketing, and Related S...
# 9           999                                        Engineering
# 3          1141                 Biological and Biomedical Sciences
# 35         1097                Visual and Performing Arts, General
#
#     participationrate_major  total_major  verbal_major  math_major
# 14                     18.0       1048.0         529.0       518.0
# ...

# %% [markdown]
# Health Professions, Business Management, and Engineering have the highest participation rates compared to others. College Board can look into these college majors whether they can adapt the test to make it more related to these field of study. So, the college might place more importance into SAT for students to get accepted into these intended majors.

# %%
#top 5 states with lowest test takers
lowtesttakers_state = df.sort_values(by='participationrate_state',ascending=True).head(5)
lowtesttakers_state
# Out:
#              state  participationrate_state  verbal_state  math_state  \
# 47  Virgin Islands                      0.0           490         445
# 39     Puerto Rico                      0.0           483         462
# 34    North Dakota                      2.0           627         636
# 52         Wyoming                      3.0           623         615
# 24     Mississippi                      3.0           628         608
#
#     total_state                         intended_major  \
# 47          935                                    NaN
# 39          944                                    NaN
# 34         1263    Transportation and Materials Moving
# 52         1238                                    NaN
# 24         1237  Parks, Recreation and Leisure Studies
#
#     participationrate_major  total_major  verbal_major  math_major
# 47                      NaN          NaN           NaN         NaN
# 39                      NaN          NaN           NaN         NaN
# ...

# %% [markdown]
# Virgin Islands, Puerto Rico, North Dakota, Wyoming, and Mississippi are states with the lowest participation rate. College Board can deep dive into schools in these states whether SAT is not recognized or resources are not well-allocated to improve participation rate in the future

# %%
#top 5 states with highest test takers
highesttakers_state = df.sort_values(by='participationrate_state',ascending=False).head(5)
highesttakers_state
# Out:
#           state  participationrate_state  verbal_state  math_state  \
# 5      Colorado                    100.0           518         506
# 6   Connecticut                    100.0           529         516
# 7      Delaware                    100.0           499         486
# 9       Florida                    100.0           516         483
# 12        Idaho                    100.0           505         488
#
#     total_state                                     intended_major  \
# 5          1024    Communication, Journalism, and Related Programs
# 6          1046  Computer and Information Sciences and Support ...
# 7           985                       Construction Trades, General
# 9           999                                        Engineering
# 12          993        Family and Consumer Sciences/Human Sciences
#
#     participationrate_major  total_major  verbal_major  math_major
# 5                       2.0       1069.0         550.0       519.0
# ...

# %%
#histogram of participation rate by state

# Size
plt.figure(figsize=(12,5))
plt.hist(df['participationrate_state'],bins=20, color='salmon');
plt.xlabel('Participation Rate in Percent');
plt.ylabel('Number of States');
plt.title('Participation Rate by State');
# colors: https://matplotlib.org/3.1.0/gallery/color/named_colors.html

# %% [markdown]
# There are 14 states with zero participation rate.

# %%
#histogram of participation rate by major

# Size
plt.figure(figsize=(12,5))
plt.hist(df['participationrate_major'],bins=20, color='yellow');
plt.xlabel('Participation Rate in Percent');
plt.ylabel('Number of College Major');
plt.title('Participation Rate by Intended College Major');
# colors: https://matplotlib.org/3.1.0/gallery/color/named_colors.html

# %% [markdown]
# Assumptions:
# Some college majors are not required SAT.
# SAT are not important factors for college admission in those majors.

# %%
#average total scores across states
total_state_mean = df['total_state'].mean()
total_state_mean
# Out:
# 1106.5283018867924

# %%
#how many states have total SAT scores above the mean
state_mean = df[df['total_state']> total_state_mean]['state']
print('States with SAT scores above the mean:\n', state_mean)
#print(state_mean.count(),'states')
# Out:
# States with SAT scores above the mean:
#  0           Alabama
# 2           Arizona
# 3          Arkansas
# 15             Iowa
# 16           Kansas
# 17         Kentucky
# 18        Louisiana
# 21    Massachusetts
# 23        Minnesota
# 24      Mississippi
# 25         Missouri
# 26          Montana
# 27         Nebraska
# 28           Nevada
# 34     North Dakota
# 37           Oregon
# 42     South Dakota
# 43        Tennessee
# 45             Utah
# 48         Virginia
# 51        Wisconsin
# 52          Wyoming
# Name: state, dtype: object

# %%
print(state_mean.count(),'states')
#the data is not equally distributed.
# Out:
# 22 states

# %% [markdown]
# There are 22 states that students have SAT scores higher than the mean. It shows that the data is not equally distributed. Some of these states may have more resources/more familiarity with SAT than others.

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
#box-plot of state math scores, and verbal scores 
df.boxplot(column=['math_state','verbal_state']);
plt.title('Boxplot of State Math scores and Verbal scores');
#plt.xlabel('Math scores','Verbal scores');

# %% [markdown]
# This boxplot shows the distribution of the state math score and verbal score.
# Students tend to do better in verbal compared to math as they have higher minimum and higher maximum scores.
# The median for verbal section is also slightly higher.
# Similar variability for both sections.
# There is no outliers for these datas.

# %%
#box-plot of intended college major math scores, and verbal scores 
df.boxplot(column=['math_major', 'verbal_major']);

plt.title('Boxplot of Intended College Major Math scores and Verbal scores');

# %% [markdown]
# This boxplot shows the distribution of the intended college major math score and verbal score. Again, students tend to do better in verbal compared to math as they have higher upper and low quartile scores. The median for verbal section is also slightly higher. The spread of math scores by intended major are higher compared to verbal and there's one outlier college major, which is those who intended to major in mathematics and statistics.

# %%
# Let's create a scatter plot of verbal scores vs. math scores by state

# Size
plt.figure(figsize=(12,5))
# Scatter plot
plt.scatter(df['verbal_state'],df['math_state'])
# Create a descriptive title
plt.title('Relationship between verbal scores and math scores by states')
# Add axis labels
plt.xlabel('Verbal scores')
plt.ylabel('Math scores')


#positive correlation
#students in certain states tend to do well in both section (if they do well, they do well in both)
# Out:
# Text(0, 0.5, 'Math scores')

# %% [markdown]
# There is a strong positive correlation in verbal scores and math scores by states.
# We can conclude that students who do well in one section, tend to do well in another section as well.
# It makes sense since generally the college would look at the total scores instead of scores per section. Hence, students need to do well as a whole to get accepted.

# %%
# Let's create a scatter plot of verbal scores vs. math scores by college major

# Size
plt.figure(figsize=(12,5))
# Scatter plot
plt.scatter(df['verbal_major'],df['math_major'])
# Create a descriptive title
plt.title('Relationship between verbal scores and math scores by intended college major')
# Add axis labels
plt.xlabel('Verbal scores')
plt.ylabel('Math scores')


#positive correlation
#less correlation compared to state
#students in certain states tend to do well in both section (if they do well, they do well in both)
# Out:
# Text(0, 0.5, 'Math scores')

# %% [markdown]
# Similar to scores by state. There is a strong positive correlation in verbal scores and math scores.
# We can conclude that students who do well in one section, tend to do well in another section as well.

# %%
# This code is taken with minor modifications from https://seaborn.pydata.org/generated/seaborn.heatmap.html
#CORRELATION MATRIX
# Establish size of figure.
plt.figure(figsize=(12,5))
# Get correlation of variables.
corr = df.corr()
corr #ranges from -1 to 1
# Out:
#                          participationrate_state  verbal_state  math_state  \
# participationrate_state                 1.000000     -0.735930   -0.682517
# verbal_state                           -0.735930      1.000000    0.984961
# math_state                             -0.682517      0.984961    1.000000
# total_state                            -0.709586      0.995752    0.996663
# participationrate_major                 0.148193     -0.213421   -0.233061
# total_major                             0.064210      0.074996    0.094820
# verbal_major                           -0.001532      0.130982    0.159543
# math_major                              0.123729      0.017473    0.028096
#
#                          total_state  participationrate_major  total_major  \
# participationrate_state    -0.709586                 0.148193     0.064210
# verbal_state                0.995752                -0.213421     0.074996
# ...

# %%
plt.scatter(df['participationrate_state'],df['total_state'])
plt.title('Relationship between Participation Rate and SAT Scores by state')
plt.xlabel('Participation Rate')
plt.ylabel('Total SAT Scores')
# Out:
# Text(0, 0.5, 'Total SAT Scores')

# %% [markdown]
# There is somewhat negative correlation between participation rate for each state and SAT scores. It shows that there are only several states that receive high SAT scores. On the other hand, there are many more states that on average have lower scores. We can conclude that high participation rate yields lower scores and vice versa.

# %%
plt.scatter(df['participationrate_major'],df['total_major'])
plt.title('Relationship between Participation Rate and SAT scores by Intended College Major')
plt.xlabel('Participation Rate')
plt.ylabel('Total SAT Scores')
# Out:
# Text(0, 0.5, 'Total SAT Scores')

# %% [markdown]
# There is also no correlation between participation rate for each intended college major and SAT scores.

# %%
plt.scatter(df['total_state'],df['total_major'])
plt.title('Relationship of SAT Scores by State and by Intended College Major')
plt.xlabel('Total SAT Scores by State',font='4')
plt.ylabel('Total SAT Scores by Intended College Major', font='4')
# Out:
# Text(0, 0.5, 'Total SAT Scores by Intended College Major')

# %% [markdown]
# There is no correlation in the SAT scores by state and the scores by college major.

# %%
plt.scatter(df['verbal_state'],df['verbal_major'])
plt.title('Relationship of SAT Verbal Scores by State and by Intended College Major')
plt.xlabel('Verbal Scores by State',font='4')
plt.ylabel('Verbal Scores by Intended College Major', font='4')
# Out:
# Text(0, 0.5, 'Verbal Scores by Intended College Major')

# %%
plt.scatter(df['math_state'],df['math_major'])
plt.title('Relationship of SAT Math Scores by State and by Intended College Major')
plt.xlabel('Math Scores by State',font='4')
plt.ylabel('Math Scores by Intended College Major', font='4')
# Out:
# Text(0, 0.5, 'Math Scores by Intended College Major')

# %%
plt.figure(figsize=(15,8))
#Set up mask to be "True" in the upper triangle.
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True  #triu = triangle upper #mask is to make it triangle
mask
# Plot our correlation heatmap, while masking the upper triangle to be white
sns.heatmap(corr,mask=mask, square=True,annot=True)  #cmap ='mako'
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df[['participationrate_state','verbal_state','math_state']])

#math and verbal scores are positively correlated
#participation rate is negatively correlated with both verbal and math scores

# %%
sns.pairplot(df[['participationrate_major','verbal_major','math_major']])
#math and verbal scores are positively correlated

# %%
#stacked histogram 
df[['verbal_state','math_state']].plot(kind='hist' ,stacked=True, bins = 30, figsize=(12,5))
plt.title('Histogram of Score in Each Section by State')
plt.legend(['Verbal Score','Math Score'])
plt.xlabel('SAT Scores',font='4')
plt.ylabel('Number of States ', font='4')
# Out:
# Text(0, 0.5, 'Number of States ')

# %% [markdown]
# The stacked histogram shows that there are more number of states that do well in math compared to those of verbal.

# %%
#stacked histogram
df[['verbal_major','math_major']].plot(kind='hist', stacked=True, bins = 30, figsize=(12,5))
plt.title('Histogram of Score in Each Section by Intended College Major')
plt.legend(['Verbal Score','Math Score'])
plt.xlabel('SAT Scores',font='4')
plt.ylabel('Number of Intended College Major ', font='4')
# Out:
# Text(0, 0.5, 'Number of Intended College Major ')

# %% [markdown]
# Similarly, the stacked histogram shows that there are more number of intended college majors that do well in math compared to those of verbal. Generally, verbal section is more difficult than math section as people tend to perform well in math no matter how we look at the data.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# **To-Do:**
# From the data I have found a lot of insights to present to our executive board. These are the key take-aways from my analysis.
#
# Scores
# - The top 5 states with highest SAT scores are states in the Midwestern area
# - On the other hand, the top 5 states with lowest SAT scores tend to be those that are not in the main US territory i.e. Puerto Roco, Virgin Islands.
# -There are 22 states that students have SAT scores higher than the mean. It shows that the data is not equally distributed. It is possible that some of these states may have more resources/more familiarity with SAT than others.
#
# Each section
# - The top 5 intended college majors with the highest total SAT scores are mainly majors that are related to Math i.e Mathematics and Statistics, Physical Science, Social Science, and Computer and Information Science.
# -Students who intended to major in science related fields also received highest scores in verbal.
# - College majors with least scores are those that tend to use less of math and verbal in the fields i.e. Mechanic and repair technology, construction trade, personal and culinary services. One assumption is these majors might not use SAT scores as a college admission test.
# -There are more number of states that do well in math compared to those of verbal.
# -Similarly, the stacked histogram shows that there are more number of intended college majors that do well in math compared to those of verbal.
# -Generally, students tend to do better in verbal compared to math as they have higher upper and lower quartile in scores.
#  The median for verbal section is also slightly higher.
#
# Participation Rates
# -There are 14 intended college majors that have zero participation rate
# -Health Professions, Business Management, and Engineering have the highest participation rates compared to others.
# -States with low participation rates are the same states with low SAT scores
#
# Correlation
# The main question that I was looking at is that "are there any correlation between states that have high SAT scores and certain intended college majors?" and the short answer is no.
# -There is no correlation in the SAT scores by state and the scores by college major.
# -There is a strong positive correlation in verbal scores and math scores.
# -There is somewhat negative correlation between participation rate for each state and SAT scores.
# -There is also no correlation between participation rate for each intended college major and SAT scores.
#
# My recommendations are to keep looking for more data on:
# -top college majors that have highest and lowest participation rate
# -states with low participation rate, specifically those 22 states with lower scores compared to the country mean
# -additional data to find correlation between states and intended college major

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
